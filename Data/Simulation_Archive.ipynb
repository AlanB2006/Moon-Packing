# %% [markdown]
# # Simulation Archive Data
#
# This notebook provides access to the simulation archive data used to generate the heat maps, plots, and related analysis figures in this repository.
#
# Because the full simulation archives are too large to store directly in the GitHub repository, the data are hosted externally in Dropbox.

# %% [markdown]
# ## Data Access
#
# The simulation archive data can be found here:
#
# **Dropbox folder:** [https://www.dropbox.com/scl/fo/yu97py3fltjvn9m26j0dh/AGyu62IdCwCo9kOuBwPxGq8?rlkey=urnsc6gg2xvguquvyoedbpwai&st=asnswsbw&dl=0]
#
# Anyone with the link should be able to view and download the archive files.

# %% [markdown]
# ## Data Description
#
# The Dropbox folder contains the simulation archive files used to produce the heat maps and figures shown in the paper/repository. These files include the numerical simulation outputs needed to reproduce or inspect the plotted results.

# %% [markdown]
# ## Notes
#
# - Download the relevant archive files before running any analysis scripts locally.
# - Keep the folder structure unchanged if using the plotting scripts provided in this repository.
# - If a script expects a specific file path, update the path to match the location where the downloaded archive files are stored on your machine.

# %%
# Example: update this path after downloading the simulation archives
data_path = "path/to/downloaded/simulation_archives"

print(f"Simulation archive data path: {data_path}")
