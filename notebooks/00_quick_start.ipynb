# %% [markdown]
# # Quick start
# Load an archived table and reproduce the Luna lifetime figure.

# %%
from moon_packing.io import read_results
from moon_packing.plotting import plot_lifetime_eccentricity
table = read_results('../data/sweeps/Luna/2_Luna_698s_final.txt')
len(table), table.n_moons

# %%
plot_lifetime_eccentricity('Luna', root='..')
